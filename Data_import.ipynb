# %% [markdown]
# **Provenance du code :** https://github.com/pmongruel/StatApp/blob/main/Data%20Process/importation_donnees.ipynb

# %% [markdown]
# This Notebook :
# - import data from French National Assembly website
# - create 3 dataset : 'database_votants_herve.csv', 'database_scrutins_herve.csv' and 'députés.csv'

# %%
import zipfile
import io
import urllib.request
import json
import pandas as pd
import pathlib
import os

# %%
path = 'C:/Users/veve1/OneDrive/Documents/ENSAE 3A/S2/Social Choice and Voting/Project/Social-Choice-and-Voting'
data_path = os.path.join(path,'Data')

# %%
access_url = urllib.request.urlopen('http://data.assemblee-nationale.fr/static/openData/repository/15/loi/scrutins/Scrutins_XV.json.zip')

data_dict=dict()

z = zipfile.ZipFile(io.BytesIO(access_url.read()))
n_scrutin = len(z.infolist())


for i in range(n_scrutin):
  data = json.loads(z.read(z.infolist()[i]).decode())
  data_dict[i] = data

# %%
from tqdm.notebook import tqdm

df_votants = pd.DataFrame(columns=['idScrutin', 'idVotant', 'vote', 'organeRefGroupe'])

for idScrutin, scrutin in tqdm(data_dict.items()):
    example = scrutin['scrutin']
    ventilation_dict = example['ventilationVotes']['organe']

    organeRefTot= ventilation_dict['organeRef']
    groupe_lists = ventilation_dict['groupes']['groupe']

    for groupe_dict in groupe_lists:
        organe_ref_groupe = groupe_dict['organeRef']
        n_groupe = groupe_dict['nombreMembresGroupe']
        vote_dict = groupe_dict['vote']

        decompteVoix_groupe_dict = vote_dict['decompteVoix']
        decompteNominatif_groupe_dict = vote_dict['decompteNominatif']

        liste_non_votant_groupe = decompteNominatif_groupe_dict['nonVotants']
        liste_pours_groupe = decompteNominatif_groupe_dict['pours']
        liste_contres_groupe = decompteNominatif_groupe_dict['contres']

        if not liste_non_votant_groupe is None:
            if type(liste_non_votant_groupe['votant']) == dict:
                df_votants = pd.concat([df_votants, pd.DataFrame({'idScrutin': [idScrutin], 'idVotant': [liste_non_votant_groupe['votant']['acteurRef']], 'vote': ['Pour'], 'organeRefGroupe': [organe_ref_groupe]})], ignore_index=True)
            else:
                df_non_votants = pd.DataFrame(columns=['idScrutin', 'idVotant', 'vote', 'organeRefGroupe'])
                for vote in liste_non_votant_groupe['votant']:
                    df_non_votants = pd.concat([df_non_votants, pd.DataFrame({'idScrutin': [idScrutin], 'idVotant': [vote['acteurRef']], 'vote': ['Non-votant'], 'organeRefGroupe': [organe_ref_groupe]})], ignore_index=True)
                df_votants = pd.concat([df_votants, df_non_votants], ignore_index=True)

        if not liste_pours_groupe is None:
            if type(liste_pours_groupe['votant']) == dict:
                df_votants = pd.concat([df_votants, pd.DataFrame({'idScrutin': [idScrutin], 'idVotant': [liste_pours_groupe['votant']['acteurRef']], 'vote': ['Pour'], 'organeRefGroupe': [organe_ref_groupe]})], ignore_index=True)
            else:
                df_pours = pd.DataFrame(columns=['idScrutin', 'idVotant', 'vote', 'organeRefGroupe'])
                for vote in liste_pours_groupe['votant']:
                    df_pours = pd.concat([df_pours, pd.DataFrame({'idScrutin': [idScrutin], 'idVotant': [vote['acteurRef']], 'vote': ['Pour'], 'organeRefGroupe': [organe_ref_groupe]})], ignore_index=True)
                df_votants = pd.concat([df_votants, df_pours], ignore_index=True)

        if not liste_contres_groupe is None:
            if type(liste_contres_groupe['votant']) == dict:
                df_votants = pd.concat([df_votants, pd.DataFrame({'idScrutin': [idScrutin], 'idVotant': [liste_contres_groupe['votant']['acteurRef']], 'vote': ['Contre'], 'organeRefGroupe': [organe_ref_groupe]})], ignore_index=True)
            else:
                df_contres = pd.DataFrame(columns=['idScrutin', 'idVotant', 'vote', 'organeRefGroupe'])
                for vote in liste_contres_groupe['votant']:
                    df_contres = pd.concat([df_contres, pd.DataFrame({'idScrutin': [idScrutin], 'idVotant': [vote['acteurRef']], 'vote': ['Contre'], 'organeRefGroupe': [organe_ref_groupe]})], ignore_index=True)
                df_votants = pd.concat([df_votants, df_contres], ignore_index=True)

# Print the concatenated DataFrame
print(df_votants)
# Out:
#   0%|          | 0/4417 [00:00<?, ?it/s]
#        idScrutin  idVotant        vote organeRefGroupe
# 0              0  PA606171  Non-votant        PO730964
# 1              0  PA721824  Non-votant        PO730964
# 2              0  PA719952        Pour        PO730964
# 3              0  PA607395        Pour        PO730964
# 4              0  PA718710        Pour        PO730964
# ...          ...       ...         ...             ...
# 450096      4416  PA335612        Pour        PO730940
# 450097      4416  PA607619      Contre        PO759900
# 450098      4416  PA719608        Pour        PO723569
# 450099      4416  PA721932        Pour        PO723569
# 450100      4416    PA1838      Contre        PO723569
#
# [450101 rows x 4 columns]

# %%
df_votants.to_csv(os.path.join(data_path,'database_votants_herve.csv'))

# %%
df_scrutin = pd.DataFrame(columns = ['idScrutin', 'date_scrutin', 'code_type_vote', 'titre', 'demandeur', 'organe_ref', 'votants', 
                                     'pour', 'contre', 'non_votants', 'non_votants_volontaires', 'abstention', 'resultat'])

for idScrutin, scrutin in data_dict.items():
    scrutin = scrutin['scrutin']
    df_temp = pd.DataFrame({'idScrutin': [idScrutin],
                            'date_scrutin': [scrutin['dateScrutin']],
                            'code_type_vote': [scrutin['typeVote']['codeTypeVote']],
                            'titre': [scrutin['titre']],
                            'demandeur': [scrutin['demandeur']['texte']],
                            'organe_ref': [scrutin['organeRef']],
                            'votants': [scrutin['syntheseVote']['nombreVotants']],
                            'pour': [scrutin['syntheseVote']['decompte']['pour']],
                            'contre': [scrutin['syntheseVote']['decompte']['contre']],
                            'non_votants': [scrutin['syntheseVote']['decompte']['nonVotants']],
                            'non_votants_volontaires': [scrutin['syntheseVote']['decompte']['nonVotantsVolontaires']],
                            'abstention': [scrutin['syntheseVote']['decompte']['abstentions']],
                            'resultat': [scrutin['sort']['code']]})
    df_scrutin = pd.concat([df_scrutin, df_temp], ignore_index=True)
df_scrutin
# Out:
#      idScrutin date_scrutin code_type_vote  \
# 0            0   2020-10-07            SPO
# 1            1   2021-02-12            SPO
# 2            2   2019-03-15            SPO
# 3            3   2019-11-13            SPO
# 4            4   2017-10-19            SPO
# ...        ...          ...            ...
# 4412      4412   2020-10-30            SPO
# 4413      4413   2021-04-16            SPO
# 4414      4414   2020-07-31            SPO
# 4415      4415   2021-07-22            SPO
# 4416      4416   2018-12-04            SPO
#
#                                                   titre  \
# 0     l'article 24 bis du projet de loi portant dive...
# 1     l'article 33 du projet de loi confortant le re...
# 2     l'amendement n°23 de M. Potier à l'article 62 ...
# 3     la motion de rejet préalable, déposée par Mme ...
# 4     l'amendement n° 400 de Mme Louwagie à l'articl...
# ...                                                 ...
# ...

# %%
df_scrutin.to_csv(os.path.join(data_path,'database_scrutins_herve.csv'))

# %%
url = 'https://data.assemblee-nationale.fr/static/openData/repository/15/amo/deputes_actifs_csv_opendata/liste_deputes_libre_office.csv'

df_deputes = pd.read_csv(url)
df_deputes.to_csv(os.path.join(data_path,'députés.csv'))
